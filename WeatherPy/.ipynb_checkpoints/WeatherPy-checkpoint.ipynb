# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from pprint import pprint

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Initializing API pull
url = "http://api.openweathermap.org/data/2.5/weather"
units = "imperial"

# Data storage
city_data = []

# Pulling data for cities
for city in cities:
        response = requests.get(url, params={ "q": city, "APPID": api_key, "units": units })
        if response.status_code == 200:
            response_json = response.json()
            city_data.append(response_json)
            print(f"Pulling data for {city}. Response: {response}")
        else:
            print(f"Cannot find city {city}.")

len(city_data)
# Out:
# Pulling data for bluff. Response: <Response [200]>
# Pulling data for carnarvon. Response: <Response [200]>
# Pulling data for busselton. Response: <Response [200]>
# Pulling data for karangasem. Response: <Response [200]>
# Pulling data for rikitea. Response: <Response [200]>
# Pulling data for sabha. Response: <Response [200]>
# Pulling data for portland. Response: <Response [200]>
# Pulling data for arraial do cabo. Response: <Response [200]>
# Pulling data for avarua. Response: <Response [200]>
# Pulling data for la macarena. Response: <Response [200]>
# Pulling data for ostrovnoy. Response: <Response [200]>
# Pulling data for hobart. Response: <Response [200]>
# Pulling data for hermanus. Response: <Response [200]>
# Pulling data for robat karim. Response: <Response [200]>
# Pulling data for san miguel. Response: <Response [200]>
# Pulling data for georgetown. Response: <Response [200]>
# Cannot find city sakakah.
# Pulling data for port alfred. Response: <Response [200]>
# Pulling data for tautira. Response: <Response [200]>
# Pulling data for kapaa. Response: <Response [200]>
# Pulling data for yar-sale. Response: <Response [200]>
# Pulling data for albany. Response: <Response [200]>
# Pulling data for grindavik. Response: <Response [200]>
# Pulling data for castro. Response: <Response [200]>
# Pulling data for mataura. Response: <Response [200]>
# Pulling data for kununurra. Response: <Response [200]>
# Cannot find city alotau.
# Pulling data for northam. Response: <Response [200]>
# Pulling data for kamariotissa. Response: <Response [200]>
# Cannot find city denau.
# Cannot find city palasa.
# Pulling data for hovd. Response: <Response [200]>
# Pulling data for cabo san lucas. Response: <Response [200]>
# Pulling data for qaanaaq. Response: <Response [200]>
# Pulling data for san patricio. Response: <Response [200]>
# Cannot find city taolanaro.
# Pulling data for lagdo. Response: <Response [200]>
# Pulling data for fortuna. Response: <Response [200]>
# Pulling data for oktyabrskiy. Response: <Response [200]>
# Pulling data for aklavik. Response: <Response [200]>
# Pulling data for makakilo city. Response: <Response [200]>
# Pulling data for ushuaia. Response: <Response [200]>
# Pulling data for sydney. Response: <Response [200]>
# Pulling data for punta arenas. Response: <Response [200]>
# Pulling data for gbarnga. Response: <Response [200]>
# Pulling data for tasiilaq. Response: <Response [200]>
# Cannot find city barentsburg.
# Pulling data for qandala. Response: <Response [200]>
# Pulling data for jamestown. Response: <Response [200]>
# Pulling data for yellowknife. Response: <Response [200]>
# Pulling data for christchurch. Response: <Response [200]>
# Pulling data for lapao. Response: <Response [200]>
# Pulling data for lebu. Response: <Response [200]>
# Pulling data for vaini. Response: <Response [200]>
# Pulling data for alofi. Response: <Response [200]>
# Pulling data for saldanha. Response: <Response [200]>
# Pulling data for cachoeira do sul. Response: <Response [200]>
# Pulling data for atuona. Response: <Response [200]>
# Pulling data for englehart. Response: <Response [200]>
# Pulling data for mahebourg. Response: <Response [200]>
# Pulling data for sal rei. Response: <Response [200]>
# Pulling data for nhulunbuy. Response: <Response [200]>
# Pulling data for rincon. Response: <Response [200]>
# Pulling data for bredasdorp. Response: <Response [200]>
# Pulling data for nyurba. Response: <Response [200]>
# Pulling data for kizukuri. Response: <Response [200]>
# Pulling data for mohacs. Response: <Response [200]>
# Pulling data for new norfolk. Response: <Response [200]>
# Pulling data for nikolskoye. Response: <Response [200]>
# Pulling data for savannakhet. Response: <Response [200]>
# Pulling data for sao geraldo do araguaia. Response: <Response [200]>
# Pulling data for lavrentiya. Response: <Response [200]>
# Cannot find city akkudah.
# Pulling data for puerto del rosario. Response: <Response [200]>
# Pulling data for sinegorskiy. Response: <Response [200]>
# Pulling data for omsukchan. Response: <Response [200]>
# Cannot find city belushya guba.
# Pulling data for conceicao do araguaia. Response: <Response [200]>
# Pulling data for tierra colorada. Response: <Response [200]>
# Cannot find city ngukurr.
# Pulling data for erenhot. Response: <Response [200]>
# Cannot find city saleaula.
# Pulling data for hilo. Response: <Response [200]>
# Pulling data for hasaki. Response: <Response [200]>
# Pulling data for molchanovo. Response: <Response [200]>
# Pulling data for mayumba. Response: <Response [200]>
# Pulling data for east london. Response: <Response [200]>
# Cannot find city palabuhanratu.
# Pulling data for san cristobal. Response: <Response [200]>
# Pulling data for kavieng. Response: <Response [200]>
# Pulling data for komsomolskiy. Response: <Response [200]>
# Pulling data for puerto plata. Response: <Response [200]>
# Pulling data for gallup. Response: <Response [200]>
# Pulling data for barrow. Response: <Response [200]>
# Pulling data for upington. Response: <Response [200]>
# Pulling data for ancud. Response: <Response [200]>
# Pulling data for airai. Response: <Response [200]>
# Pulling data for peniche. Response: <Response [200]>
# Pulling data for lyubinskiy. Response: <Response [200]>
# Cannot find city vaitupu.
# Pulling data for newport. Response: <Response [200]>
# Cannot find city bengkulu.
# Pulling data for berlevag. Response: <Response [200]>
# Pulling data for la ronge. Response: <Response [200]>
# Pulling data for saskylakh. Response: <Response [200]>
# Pulling data for mersing. Response: <Response [200]>
# Cannot find city illoqqortoormiut.
# Pulling data for aykhal. Response: <Response [200]>
# Pulling data for merauke. Response: <Response [200]>
# Pulling data for norman wells. Response: <Response [200]>
# Cannot find city kerki.
# Pulling data for hithadhoo. Response: <Response [200]>
# Pulling data for saint-philippe. Response: <Response [200]>
# Pulling data for mar del plata. Response: <Response [200]>
# Pulling data for orotukan. Response: <Response [200]>
# Pulling data for sabya. Response: <Response [200]>
# Pulling data for hastings. Response: <Response [200]>
# Pulling data for ilulissat. Response: <Response [200]>
# Pulling data for huarmey. Response: <Response [200]>
# Pulling data for sao joao da barra. Response: <Response [200]>
# Pulling data for torbay. Response: <Response [200]>
# Pulling data for suntar. Response: <Response [200]>
# Pulling data for baoqing. Response: <Response [200]>
# Cannot find city rungata.
# Pulling data for hamilton. Response: <Response [200]>
# Pulling data for dalbandin. Response: <Response [200]>
# Cannot find city grand river south east.
# Pulling data for vanimo. Response: <Response [200]>
# Pulling data for geraldton. Response: <Response [200]>
# Pulling data for chuy. Response: <Response [200]>
# Pulling data for ahipara. Response: <Response [200]>
# Pulling data for ponta do sol. Response: <Response [200]>
# Pulling data for qeshm. Response: <Response [200]>
# Pulling data for maceio. Response: <Response [200]>
# Pulling data for lac du bonnet. Response: <Response [200]>
# Pulling data for dikson. Response: <Response [200]>
# Pulling data for grand bank. Response: <Response [200]>
# Cannot find city sorvag.
# Pulling data for tinaquillo. Response: <Response [200]>
# Pulling data for campbell river. Response: <Response [200]>
# Pulling data for dingle. Response: <Response [200]>
# Pulling data for flin flon. Response: <Response [200]>
# Pulling data for katsuura. Response: <Response [200]>
# Pulling data for san fernando. Response: <Response [200]>
# Pulling data for buala. Response: <Response [200]>
# Pulling data for upernavik. Response: <Response [200]>
# Pulling data for khatanga. Response: <Response [200]>
# Pulling data for port lincoln. Response: <Response [200]>
# Pulling data for dehloran. Response: <Response [200]>
# Pulling data for kaitangata. Response: <Response [200]>
# Pulling data for havre-saint-pierre. Response: <Response [200]>
# Pulling data for rawson. Response: <Response [200]>
# Pulling data for tuktoyaktuk. Response: <Response [200]>
# Pulling data for wagar. Response: <Response [200]>
# Pulling data for lima. Response: <Response [200]>
# Pulling data for bara. Response: <Response [200]>
# Pulling data for sao jose de ribamar. Response: <Response [200]>
# Pulling data for borkenes. Response: <Response [200]>
# Pulling data for miraflores. Response: <Response [200]>
# Pulling data for vestmanna. Response: <Response [200]>
# Pulling data for scarborough. Response: <Response [200]>
# Pulling data for sohagpur. Response: <Response [200]>
# Pulling data for creel. Response: <Response [200]>
# Pulling data for galesong. Response: <Response [200]>
# Pulling data for iguape. Response: <Response [200]>
# Pulling data for lasa. Response: <Response [200]>
# Cannot find city amderma.
# Pulling data for nchelenge. Response: <Response [200]>
# Pulling data for praia da vitoria. Response: <Response [200]>
# Pulling data for puerto ayora. Response: <Response [200]>
# Cannot find city karaul.
# Pulling data for bethel. Response: <Response [200]>
# Cannot find city nizhneyansk.
# Pulling data for oksfjord. Response: <Response [200]>
# Pulling data for kupang. Response: <Response [200]>
# Pulling data for ribeira grande. Response: <Response [200]>
# Pulling data for hay river. Response: <Response [200]>
# Pulling data for bobrovytsya. Response: <Response [200]>
# Pulling data for iqaluit. Response: <Response [200]>
# Pulling data for igarka. Response: <Response [200]>
# Pulling data for aboisso. Response: <Response [200]>
# Pulling data for kormilovka. Response: <Response [200]>
# Pulling data for teguldet. Response: <Response [200]>
# Pulling data for labuhan. Response: <Response [200]>
# Pulling data for yaan. Response: <Response [200]>
# Pulling data for pacific grove. Response: <Response [200]>
# Pulling data for grand forks. Response: <Response [200]>
# Pulling data for prince george. Response: <Response [200]>
# Pulling data for kahului. Response: <Response [200]>
# Pulling data for ugoofaaru. Response: <Response [200]>
# Pulling data for dawlatabad. Response: <Response [200]>
# Pulling data for mount gambier. Response: <Response [200]>
# Pulling data for yerbogachen. Response: <Response [200]>
# Pulling data for castanos. Response: <Response [200]>
# Pulling data for esperance. Response: <Response [200]>
# Pulling data for madang. Response: <Response [200]>
# Pulling data for emiliano zapata. Response: <Response [200]>
# Pulling data for betsiamites. Response: <Response [200]>
# Pulling data for thinadhoo. Response: <Response [200]>
# Pulling data for shirokiy. Response: <Response [200]>
# Pulling data for roanoke rapids. Response: <Response [200]>
# Pulling data for ventspils. Response: <Response [200]>
# Pulling data for meulaboh. Response: <Response [200]>
# Pulling data for cape town. Response: <Response [200]>
# Pulling data for ekibastuz. Response: <Response [200]>
# Pulling data for cidreira. Response: <Response [200]>
# Pulling data for araouane. Response: <Response [200]>
# Pulling data for butaritari. Response: <Response [200]>
# Pulling data for maragogi. Response: <Response [200]>
# Pulling data for cherskiy. Response: <Response [200]>
# Pulling data for moravske budejovice. Response: <Response [200]>
# Cannot find city aflu.
# Pulling data for nizwa. Response: <Response [200]>
# Pulling data for mouila. Response: <Response [200]>
# Pulling data for chapais. Response: <Response [200]>
# Pulling data for ippy. Response: <Response [200]>
# Pulling data for jalu. Response: <Response [200]>
# Pulling data for asasa. Response: <Response [200]>
# Pulling data for wewak. Response: <Response [200]>
# Pulling data for autazes. Response: <Response [200]>
# Pulling data for ouadda. Response: <Response [200]>
# Pulling data for tiksi. Response: <Response [200]>
# Pulling data for energetik. Response: <Response [200]>
# Pulling data for gat. Response: <Response [200]>
# Pulling data for bambous virieux. Response: <Response [200]>
# Pulling data for clyde river. Response: <Response [200]>
# Cannot find city tsihombe.
# Pulling data for bulalacao. Response: <Response [200]>
# Pulling data for talas. Response: <Response [200]>
# Cannot find city olafsvik.
# Pulling data for teya. Response: <Response [200]>
# Pulling data for ghanzi. Response: <Response [200]>
# Pulling data for ayr. Response: <Response [200]>
# Pulling data for empangeni. Response: <Response [200]>
# Pulling data for leningradskiy. Response: <Response [200]>
# Pulling data for waingapu. Response: <Response [200]>
# Pulling data for codrington. Response: <Response [200]>
# Pulling data for hualmay. Response: <Response [200]>
# Pulling data for calvinia. Response: <Response [200]>
# Pulling data for bollnas. Response: <Response [200]>
# Pulling data for avera. Response: <Response [200]>
# Pulling data for balakhninskiy. Response: <Response [200]>
# Pulling data for san isidro. Response: <Response [200]>
# Pulling data for beidao. Response: <Response [200]>
# Pulling data for sisimiut. Response: <Response [200]>
# Pulling data for talnakh. Response: <Response [200]>
# Pulling data for adrar. Response: <Response [200]>
# Pulling data for melchor de mencos. Response: <Response [200]>
# Pulling data for boaco. Response: <Response [200]>
# Pulling data for cayenne. Response: <Response [200]>
# Pulling data for carauari. Response: <Response [200]>
# Cannot find city yuzhno-yeniseyskiy.
# Cannot find city bac lieu.
# Pulling data for mago. Response: <Response [200]>
# Pulling data for poum. Response: <Response [200]>
# Pulling data for praya. Response: <Response [200]>
# Pulling data for casambalangan. Response: <Response [200]>
# Cannot find city umm durman.
# Cannot find city dzhusaly.
# Pulling data for saint george. Response: <Response [200]>
# Pulling data for jiangyou. Response: <Response [200]>
# Cannot find city asau.
# Pulling data for acapulco. Response: <Response [200]>
# Pulling data for pringsewu. Response: <Response [200]>
# Pulling data for batticaloa. Response: <Response [200]>
# Pulling data for cedeno. Response: <Response [200]>
# Pulling data for olinda. Response: <Response [200]>
# Pulling data for port hardy. Response: <Response [200]>
# Cannot find city karamea.
# Pulling data for hervey bay. Response: <Response [200]>
# Pulling data for basoko. Response: <Response [200]>
# Pulling data for xichang. Response: <Response [200]>
# Pulling data for mazatlan. Response: <Response [200]>
# Pulling data for san francisco. Response: <Response [200]>
# Pulling data for sao filipe. Response: <Response [200]>
# Pulling data for vanavara. Response: <Response [200]>
# Pulling data for lorengau. Response: <Response [200]>
# Pulling data for gayny. Response: <Response [200]>
# Pulling data for tuatapere. Response: <Response [200]>
# Pulling data for cockburn town. Response: <Response [200]>
# Pulling data for sladkovo. Response: <Response [200]>
# Pulling data for kieta. Response: <Response [200]>
# Pulling data for coos bay. Response: <Response [200]>
# Pulling data for znamenskoye. Response: <Response [200]>
# Pulling data for vangaindrano. Response: <Response [200]>
# Pulling data for otane. Response: <Response [200]>
# Pulling data for namibe. Response: <Response [200]>
# Pulling data for japura. Response: <Response [200]>
# Pulling data for los banos. Response: <Response [200]>
# Pulling data for riyadh. Response: <Response [200]>
# Cannot find city jabiru.
# Pulling data for darhan. Response: <Response [200]>
# Pulling data for forio. Response: <Response [200]>
# Pulling data for zruc nad sazavou. Response: <Response [200]>
# Pulling data for shingu. Response: <Response [200]>
# Pulling data for tazovskiy. Response: <Response [200]>
# Pulling data for zevenaar. Response: <Response [200]>
# Pulling data for pemba. Response: <Response [200]>
# Pulling data for kovur. Response: <Response [200]>
# Pulling data for pochutla. Response: <Response [200]>
# Pulling data for victoria. Response: <Response [200]>
# Pulling data for narsaq. Response: <Response [200]>
# Pulling data for kiruna. Response: <Response [200]>
# Pulling data for bayan. Response: <Response [200]>
# Pulling data for san carlos. Response: <Response [200]>
# Pulling data for naryan-mar. Response: <Response [200]>
# Pulling data for sinnamary. Response: <Response [200]>
# Pulling data for bathsheba. Response: <Response [200]>
# Pulling data for salalah. Response: <Response [200]>
# Pulling data for panorama. Response: <Response [200]>
# Pulling data for roswell. Response: <Response [200]>
# Pulling data for sistranda. Response: <Response [200]>
# Pulling data for pyaozerskiy. Response: <Response [200]>
# Pulling data for kavaratti. Response: <Response [200]>
# Pulling data for longyearbyen. Response: <Response [200]>
# Pulling data for kalmunai. Response: <Response [200]>
# Pulling data for blitar. Response: <Response [200]>
# Pulling data for nexo. Response: <Response [200]>
# Pulling data for champerico. Response: <Response [200]>
# Pulling data for hofn. Response: <Response [200]>
# Cannot find city cockburn harbour.
# Pulling data for tagab. Response: <Response [200]>
# Pulling data for novyy nekouz. Response: <Response [200]>
# Pulling data for horsham. Response: <Response [200]>
# Pulling data for okoneshnikovo. Response: <Response [200]>
# Pulling data for nouadhibou. Response: <Response [200]>
# Pulling data for margate. Response: <Response [200]>
# Pulling data for lata. Response: <Response [200]>
# Pulling data for sorland. Response: <Response [200]>
# Pulling data for shakiso. Response: <Response [200]>
# Pulling data for stephenville. Response: <Response [200]>
# Pulling data for magugu. Response: <Response [200]>
# Pulling data for voyvozh. Response: <Response [200]>
# Pulling data for raybag. Response: <Response [200]>
# Pulling data for athabasca. Response: <Response [200]>
# Pulling data for richards bay. Response: <Response [200]>
# Pulling data for thompson. Response: <Response [200]>
# Pulling data for nishihara. Response: <Response [200]>
# Pulling data for vila velha. Response: <Response [200]>
# Pulling data for charleville-mezieres. Response: <Response [200]>
# Pulling data for tottori. Response: <Response [200]>
# Cannot find city skalistyy.
# Pulling data for los angeles. Response: <Response [200]>
# Pulling data for batagay-alyta. Response: <Response [200]>
# Pulling data for tilichiki. Response: <Response [200]>
# Pulling data for yeppoon. Response: <Response [200]>
# Pulling data for rosarito. Response: <Response [200]>
# Pulling data for shimoda. Response: <Response [200]>
# Pulling data for cascais. Response: <Response [200]>
# Pulling data for tyrma. Response: <Response [200]>
# Pulling data for tabuny. Response: <Response [200]>
# Pulling data for barlinek. Response: <Response [200]>
# Pulling data for lethem. Response: <Response [200]>
# Cannot find city phan rang.
# Pulling data for taoudenni. Response: <Response [200]>
# Pulling data for nioki. Response: <Response [200]>
# Cannot find city mys shmidta.
# Pulling data for berekum. Response: <Response [200]>
# Pulling data for marsh harbour. Response: <Response [200]>
# Pulling data for russkiy. Response: <Response [200]>
# Pulling data for souillac. Response: <Response [200]>
# Pulling data for kodiak. Response: <Response [200]>
# Pulling data for santiago del estero. Response: <Response [200]>
# Pulling data for caravelas. Response: <Response [200]>
# Pulling data for ponta delgada. Response: <Response [200]>
# Pulling data for bereda. Response: <Response [200]>
# Pulling data for eufaula. Response: <Response [200]>
# Pulling data for klaksvik. Response: <Response [200]>
# Pulling data for sur. Response: <Response [200]>
# Cannot find city tawnat.
# Pulling data for wukari. Response: <Response [200]>
# Pulling data for bonthe. Response: <Response [200]>
# Pulling data for charters towers. Response: <Response [200]>
# Pulling data for san felipe. Response: <Response [200]>
# Pulling data for vestmannaeyjar. Response: <Response [200]>
# Pulling data for coahuayana. Response: <Response [200]>
# Pulling data for suibara. Response: <Response [200]>
# Pulling data for constantine. Response: <Response [200]>
# Pulling data for vilyuysk. Response: <Response [200]>
# Pulling data for magistralnyy. Response: <Response [200]>
# Pulling data for ust-kuyga. Response: <Response [200]>
# Pulling data for iralaya. Response: <Response [200]>
# Pulling data for dobra. Response: <Response [200]>
# Pulling data for umm lajj. Response: <Response [200]>
# Pulling data for karratha. Response: <Response [200]>
# Pulling data for belaya gora. Response: <Response [200]>
# Pulling data for north bend. Response: <Response [200]>
# Pulling data for malinovskiy. Response: <Response [200]>
# Cannot find city asfi.
# Pulling data for faanui. Response: <Response [200]>
# Pulling data for baft. Response: <Response [200]>
# Pulling data for qasigiannguit. Response: <Response [200]>
# Pulling data for kuching. Response: <Response [200]>
# Pulling data for vallenar. Response: <Response [200]>
# Pulling data for coihaique. Response: <Response [200]>
# Pulling data for mission bend. Response: <Response [200]>
# Pulling data for yacuiba. Response: <Response [200]>
# Pulling data for bandarbeyla. Response: <Response [200]>
# Pulling data for kutum. Response: <Response [200]>
# Pulling data for kendal. Response: <Response [200]>
# Pulling data for borogontsy. Response: <Response [200]>
# Pulling data for mana. Response: <Response [200]>
# Pulling data for antalaha. Response: <Response [200]>
# Pulling data for ternate. Response: <Response [200]>
# Cannot find city sentyabrskiy.
# Pulling data for inirida. Response: <Response [200]>
# Pulling data for lincoln. Response: <Response [200]>
# Cannot find city pafos.
# Pulling data for saint-francois. Response: <Response [200]>
# Pulling data for pacifica. Response: <Response [200]>
# Pulling data for husavik. Response: <Response [200]>
# Cannot find city hunza.
# Pulling data for malartic. Response: <Response [200]>
# Pulling data for vila franca do campo. Response: <Response [200]>
# Pulling data for port elizabeth. Response: <Response [200]>
# Pulling data for urdoma. Response: <Response [200]>
# Pulling data for kruisfontein. Response: <Response [200]>
# Pulling data for oistins. Response: <Response [200]>
# Pulling data for henties bay. Response: <Response [200]>
# Pulling data for sayyan. Response: <Response [200]>
# Pulling data for benguela. Response: <Response [200]>
# Pulling data for biak. Response: <Response [200]>
# Pulling data for jatai. Response: <Response [200]>
# Cannot find city geresk.
# Pulling data for ohara. Response: <Response [200]>
# Pulling data for qaqortoq. Response: <Response [200]>
# Pulling data for hokitika. Response: <Response [200]>
# Pulling data for shubarkuduk. Response: <Response [200]>
# Pulling data for lahij. Response: <Response [200]>
# Pulling data for deputatskiy. Response: <Response [200]>
# Pulling data for soe. Response: <Response [200]>
# Pulling data for urengoy. Response: <Response [200]>
# Pulling data for provideniya. Response: <Response [200]>
# Pulling data for hambantota. Response: <Response [200]>
# Pulling data for saint-augustin. Response: <Response [200]>
# Pulling data for guerrero negro. Response: <Response [200]>
# Pulling data for ipanema. Response: <Response [200]>
# Pulling data for nurobod. Response: <Response [200]>
# Pulling data for seminole. Response: <Response [200]>
# Pulling data for tessalit. Response: <Response [200]>
# Pulling data for tzaneen. Response: <Response [200]>
# Pulling data for nanortalik. Response: <Response [200]>
# Cannot find city duz.
# Pulling data for mwinilunga. Response: <Response [200]>
# Pulling data for kabala. Response: <Response [200]>
# Cannot find city mangile.
# Pulling data for san quintin. Response: <Response [200]>
# Pulling data for luziania. Response: <Response [200]>
# Cannot find city sembe.
# Pulling data for ntchisi. Response: <Response [200]>
# Pulling data for asyut. Response: <Response [200]>
# Pulling data for moose factory. Response: <Response [200]>
# Cannot find city ust-kamchatsk.
# Pulling data for saint-joseph. Response: <Response [200]>
# Pulling data for pevek. Response: <Response [200]>
# Pulling data for ravar. Response: <Response [200]>
# Pulling data for atherton. Response: <Response [200]>
# Pulling data for bubaque. Response: <Response [200]>
# Pulling data for port hueneme. Response: <Response [200]>
# Pulling data for payson. Response: <Response [200]>
# Pulling data for wajima. Response: <Response [200]>
# Pulling data for bemidji. Response: <Response [200]>
# Cannot find city lolua.
# Pulling data for banda aceh. Response: <Response [200]>
# Pulling data for grand-lahou. Response: <Response [200]>
# Cannot find city bolungarvik.
# Pulling data for wells. Response: <Response [200]>
# Pulling data for nador. Response: <Response [200]>
# Pulling data for nisia floresta. Response: <Response [200]>
# Cannot find city bocaranga.
# Pulling data for taunggyi. Response: <Response [200]>
# Pulling data for khasan. Response: <Response [200]>
# Pulling data for aksu. Response: <Response [200]>
# Pulling data for witu. Response: <Response [200]>
# Pulling data for loukhi. Response: <Response [200]>
# Cannot find city umzimvubu.
# Pulling data for luderitz. Response: <Response [200]>
# Pulling data for katima mulilo. Response: <Response [200]>
# Pulling data for ibra. Response: <Response [200]>
# Pulling data for zhigansk. Response: <Response [200]>
# Pulling data for elizabeth city. Response: <Response [200]>
# Pulling data for kobryn. Response: <Response [200]>
# Pulling data for kosonsoy. Response: <Response [200]>
# Pulling data for mahenge. Response: <Response [200]>
# Cannot find city samusu.
# Pulling data for puerto colombia. Response: <Response [200]>
# Pulling data for aswan. Response: <Response [200]>
# Pulling data for sena madureira. Response: <Response [200]>
# Pulling data for hargeysa. Response: <Response [200]>
# Pulling data for chokurdakh. Response: <Response [200]>
# Pulling data for sorong. Response: <Response [200]>
# Pulling data for severo-kurilsk. Response: <Response [200]>
# Pulling data for katobu. Response: <Response [200]>
# Pulling data for santa vitoria. Response: <Response [200]>
# Pulling data for eyl. Response: <Response [200]>
# Pulling data for kamenka. Response: <Response [200]>
# Pulling data for grand gaube. Response: <Response [200]>
# Pulling data for constitucion. Response: <Response [200]>
# Pulling data for zaraza. Response: <Response [200]>
# Cannot find city tumannyy.
# Pulling data for abu kamal. Response: <Response [200]>
# Pulling data for pisco. Response: <Response [200]>
# Pulling data for itarema. Response: <Response [200]>
# Pulling data for velasco ibarra. Response: <Response [200]>
# Pulling data for meadow lake. Response: <Response [200]>
# Pulling data for kenai. Response: <Response [200]>
# Pulling data for seydi. Response: <Response [200]>
# Pulling data for zwedru. Response: <Response [200]>
# Pulling data for independencia. Response: <Response [200]>
# Pulling data for san estanislao. Response: <Response [200]>
# Cannot find city korla.
# Pulling data for viransehir. Response: <Response [200]>
# Pulling data for kantunilkin. Response: <Response [200]>
# Pulling data for sangar. Response: <Response [200]>
# Pulling data for plouzane. Response: <Response [200]>
# Pulling data for yulara. Response: <Response [200]>
# Pulling data for riberalta. Response: <Response [200]>
# Pulling data for bijie. Response: <Response [200]>
# Pulling data for murindo. Response: <Response [200]>
# Pulling data for nabire. Response: <Response [200]>
# Pulling data for leon valley. Response: <Response [200]>
# Pulling data for kambove. Response: <Response [200]>
# Cannot find city tuggurt.
# Pulling data for santa isabel do rio negro. Response: <Response [200]>
# Cannot find city katsiveli.
# Pulling data for genhe. Response: <Response [200]>
# Pulling data for isangel. Response: <Response [200]>
# Pulling data for byron bay. Response: <Response [200]>
# Pulling data for namatanai. Response: <Response [200]>
# Pulling data for marinette. Response: <Response [200]>
# Pulling data for verkhnyaya inta. Response: <Response [200]>
# Pulling data for haines junction. Response: <Response [200]>
# Pulling data for iquique. Response: <Response [200]>
# Pulling data for workington. Response: <Response [200]>
# Pulling data for kaeo. Response: <Response [200]>
# Pulling data for kodinsk. Response: <Response [200]>
# Pulling data for aloleng. Response: <Response [200]>
# Pulling data for bhimunipatnam. Response: <Response [200]>
# Pulling data for emerald. Response: <Response [200]>
# Pulling data for camacha. Response: <Response [200]>
# Pulling data for kampong cham. Response: <Response [200]>
# Pulling data for necochea. Response: <Response [200]>
# Pulling data for benjamin constant. Response: <Response [200]>
# Pulling data for port keats. Response: <Response [200]>
# Pulling data for hami. Response: <Response [200]>
# Pulling data for surt. Response: <Response [200]>
# Pulling data for aksha. Response: <Response [200]>
# Pulling data for swellendam. Response: <Response [200]>
# Cannot find city maloshuyka.
# Pulling data for baglung. Response: <Response [200]>
# Pulling data for cervo. Response: <Response [200]>
# Pulling data for petropavlovsk-kamchatskiy. Response: <Response [200]>
# Pulling data for flagstaff. Response: <Response [200]>
# Pulling data for maningrida. Response: <Response [200]>
# Pulling data for sarangani. Response: <Response [200]>
# Pulling data for khirkiya. Response: <Response [200]>
# Pulling data for okhotsk. Response: <Response [200]>
# Pulling data for upata. Response: <Response [200]>
# Pulling data for lompoc. Response: <Response [200]>
# Cannot find city asayita.
# Pulling data for luancheng. Response: <Response [200]>
# Pulling data for kang. Response: <Response [200]>
# Pulling data for khani. Response: <Response [200]>
# Pulling data for arinos. Response: <Response [200]>
# Pulling data for ambilobe. Response: <Response [200]>
# Pulling data for helong. Response: <Response [200]>
# Pulling data for saveh. Response: <Response [200]>
# Pulling data for savelugu. Response: <Response [200]>
# Pulling data for goderich. Response: <Response [200]>
# Pulling data for quatre cocos. Response: <Response [200]>
# Pulling data for veraval. Response: <Response [200]>
# Pulling data for namtsy. Response: <Response [200]>
# Pulling data for fairfield. Response: <Response [200]>
# Pulling data for tefe. Response: <Response [200]>
# Pulling data for puerto escondido. Response: <Response [200]>
# Cannot find city buqayq.
# Pulling data for vardo. Response: <Response [200]>
# Pulling data for sikonge. Response: <Response [200]>
# Pulling data for arman. Response: <Response [200]>
# Pulling data for huilong. Response: <Response [200]>
# Pulling data for taylorville. Response: <Response [200]>
# Pulling data for touros. Response: <Response [200]>
# Pulling data for makat. Response: <Response [200]>
# Pulling data for phuket. Response: <Response [200]>
# Pulling data for saint-prosper. Response: <Response [200]>
# Cannot find city toliary.
# Pulling data for ucluelet. Response: <Response [200]>
# Pulling data for baghramyan. Response: <Response [200]>
# Pulling data for marawi. Response: <Response [200]>
# Pulling data for lufilufi. Response: <Response [200]>
# Pulling data for naze. Response: <Response [200]>
# Cannot find city toftir.
# Pulling data for altay. Response: <Response [200]>
# Cannot find city laiagam.
# Pulling data for muyezerskiy. Response: <Response [200]>
# Pulling data for beringovskiy. Response: <Response [200]>
# Pulling data for oum hadjer. Response: <Response [200]>
# Pulling data for bani walid. Response: <Response [200]>
# Pulling data for makokou. Response: <Response [200]>
# Pulling data for adavere. Response: <Response [200]>
# Pulling data for yuanping. Response: <Response [200]>
# Pulling data for ketchikan. Response: <Response [200]>
# Pulling data for kaputa. Response: <Response [200]>
# Pulling data for nicoya. Response: <Response [200]>
# Pulling data for valleyview. Response: <Response [200]>
# Pulling data for salinopolis. Response: <Response [200]>
# Pulling data for estevan. Response: <Response [200]>
# Pulling data for lat yao. Response: <Response [200]>
# Pulling data for tunceli. Response: <Response [200]>
# Pulling data for florida. Response: <Response [200]>
# Pulling data for uhlove. Response: <Response [200]>
# Pulling data for bela. Response: <Response [200]>
# Pulling data for nanpara. Response: <Response [200]>
# Pulling data for saint-pierre. Response: <Response [200]>
# Pulling data for bouna. Response: <Response [200]>
# Cannot find city bairiki.
# Pulling data for muisne. Response: <Response [200]>
# Pulling data for coquimbo. Response: <Response [200]>
# Cannot find city mullaitivu.
# 557

# %%
pprint(city_data[0])
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1569334088,
#  'id': 2175403,
#  'main': {'grnd_level': 1001.99,
#           'humidity': 88,
#           'pressure': 1022.52,
#           'sea_level': 1022.52,
#           'temp': 63.05,
#           'temp_max': 63.05,
#           'temp_min': 63.05},
#  'name': 'Bluff',
#  'sys': {'country': 'AU',
#          'message': 0.0081,
#          'sunrise': 1569354663,
#          'sunset': 1569398419},
#  'timezone': 36000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 118.733, 'speed': 10.33}}

# %%
names =[]
clouds =[]
lats = []
lons = []
countries = []
dates = []
maxtemps = []
windspds = []
humids = []

for cities in city_data:
    names.append(cities['name'])
    clouds.append(cities['clouds']['all'])
    lats.append(cities['coord']['lat'])
    lons.append(cities['coord']['lon'])
    countries.append(cities['sys']['country'])
    dates.append(cities['dt'])
    maxtemps.append(cities['main']['temp_max'])
    windspds.append(cities['wind']['speed'])
    humids.append(cities['main']['humidity'])

cities_df = pd.DataFrame({"City":names,"Cloudiness":clouds,"Country":countries,"Date":dates,"Humidity":humids,
                          "Latitude":lats,"Longitude":lons,"Max Temp (F)":maxtemps,"Wind Speed":windspds})
cities_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0       Bluff         100      AU  1569334088        88    -23.58     149.07
# 1   Carnarvon           0      ZA  1569334088        25    -30.97      22.13
# 2   Busselton          24      AU  1569334088        66    -33.64     115.35
# 3  Karangasem           0      ID  1569334088        82     -6.70     108.49
# 4     Rikitea          63      PF  1569334089        73    -23.12    -134.97
#
#    Max Temp (F)  Wind Speed
# 0         63.05       10.33
# 1         67.19       22.68
# 2         55.99       11.03
# 3         74.57        4.74
# 4         69.71       10.38

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
cities_df.plot(kind="scatter",x="Latitude",y="Max Temp (F)")
plt.grid()
plt.title("Maximum Temperatures based on Latitude")
plt.show()
plt.savefig("DataFigs/temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
cities_df.plot(kind="scatter",x="Latitude",y="Humidity")
plt.grid()
plt.title("Humidity based on Latitude")
plt.show()
plt.savefig("DataFigs/humid.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cities_df.plot(kind="scatter",x="Latitude",y="Cloudiness")
plt.grid()
plt.title("Cloudiness based on Latitude")
plt.show()
plt.savefig("DataFigs/clouds.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
cities_df.plot(kind="scatter",x="Latitude",y="Wind Speed")
plt.grid()
plt.title("Wind Speeds based on Latitude")
plt.show()
plt.savefig("DataFigs/wind_spd.png")

# %%
cities_df.to_csv("DataFigs/city_data.csv")

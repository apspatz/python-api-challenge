# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from pprint import pprint

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Initializing API pull
url = "http://api.openweathermap.org/data/2.5/weather"
units = "imperial"

# Data storage
city_data = []

# Pulling data for cities
for city in cities:
        response = requests.get(url, params={ "q": city, "APPID": api_key, "units": units })
        if response.status_code == 200:
            response_json = response.json()
            city_data.append(response_json)
            print(f"Pulling data for {city}. Response: {response}")
        else:
            print(f"Cannot find city {city}.")

# Checking for Minimal City Count
len(city_data)
# Out:
# Pulling data for lorengau. Response: <Response [200]>
# Pulling data for tevaitoa. Response: <Response [200]>
# Cannot find city taolanaro.
# Cannot find city okandja.
# Pulling data for sept-iles. Response: <Response [200]>
# Pulling data for gigmoto. Response: <Response [200]>
# Pulling data for albany. Response: <Response [200]>
# Pulling data for churapcha. Response: <Response [200]>
# Pulling data for tasiilaq. Response: <Response [200]>
# Pulling data for hobart. Response: <Response [200]>
# Pulling data for cape town. Response: <Response [200]>
# Pulling data for port alfred. Response: <Response [200]>
# Pulling data for vila velha. Response: <Response [200]>
# Pulling data for tatarsk. Response: <Response [200]>
# Pulling data for tres passos. Response: <Response [200]>
# Pulling data for bredasdorp. Response: <Response [200]>
# Pulling data for nikolskoye. Response: <Response [200]>
# Pulling data for baiyin. Response: <Response [200]>
# Pulling data for ushuaia. Response: <Response [200]>
# Pulling data for chuy. Response: <Response [200]>
# Pulling data for rikitea. Response: <Response [200]>
# Pulling data for nanortalik. Response: <Response [200]>
# Pulling data for sinnamary. Response: <Response [200]>
# Cannot find city barentsburg.
# Pulling data for arraial do cabo. Response: <Response [200]>
# Pulling data for meulaboh. Response: <Response [200]>
# Pulling data for mataura. Response: <Response [200]>
# Cannot find city mys shmidta.
# Pulling data for busselton. Response: <Response [200]>
# Pulling data for nueve de julio. Response: <Response [200]>
# Pulling data for thiruvananthapuram. Response: <Response [200]>
# Pulling data for qaanaaq. Response: <Response [200]>
# Pulling data for yellowknife. Response: <Response [200]>
# Pulling data for uray. Response: <Response [200]>
# Pulling data for xihua. Response: <Response [200]>
# Pulling data for cabo san lucas. Response: <Response [200]>
# Pulling data for poum. Response: <Response [200]>
# Pulling data for hilo. Response: <Response [200]>
# Pulling data for portland. Response: <Response [200]>
# Pulling data for ponta do sol. Response: <Response [200]>
# Pulling data for ancud. Response: <Response [200]>
# Cannot find city amderma.
# Pulling data for kant. Response: <Response [200]>
# Pulling data for aripuana. Response: <Response [200]>
# Pulling data for tralee. Response: <Response [200]>
# Pulling data for san quintin. Response: <Response [200]>
# Pulling data for provideniya. Response: <Response [200]>
# Pulling data for ilulissat. Response: <Response [200]>
# Pulling data for bluff. Response: <Response [200]>
# Pulling data for salisbury. Response: <Response [200]>
# Pulling data for ribeira grande. Response: <Response [200]>
# Cannot find city sorvag.
# Pulling data for ostrovnoy. Response: <Response [200]>
# Pulling data for contamana. Response: <Response [200]>
# Pulling data for diego de almagro. Response: <Response [200]>
# Pulling data for chhoti sadri. Response: <Response [200]>
# Pulling data for puerto ayora. Response: <Response [200]>
# Pulling data for aklavik. Response: <Response [200]>
# Pulling data for dikson. Response: <Response [200]>
# Cannot find city saleaula.
# Pulling data for constantine. Response: <Response [200]>
# Pulling data for antofagasta. Response: <Response [200]>
# Pulling data for sao joao da barra. Response: <Response [200]>
# Pulling data for khatanga. Response: <Response [200]>
# Pulling data for new norfolk. Response: <Response [200]>
# Cannot find city rawannawi.
# Cannot find city kushmurun.
# Pulling data for itarema. Response: <Response [200]>
# Cannot find city grand river south east.
# Pulling data for thompson. Response: <Response [200]>
# Pulling data for puri. Response: <Response [200]>
# Pulling data for punta arenas. Response: <Response [200]>
# Pulling data for rocha. Response: <Response [200]>
# Pulling data for pljevlja. Response: <Response [200]>
# Pulling data for jiuquan. Response: <Response [200]>
# Pulling data for vaini. Response: <Response [200]>
# Pulling data for sitka. Response: <Response [200]>
# Pulling data for zacamulpa. Response: <Response [200]>
# Pulling data for avarua. Response: <Response [200]>
# Pulling data for tuktoyaktuk. Response: <Response [200]>
# Pulling data for ihosy. Response: <Response [200]>
# Pulling data for alofi. Response: <Response [200]>
# Pulling data for torbay. Response: <Response [200]>
# Pulling data for marsh harbour. Response: <Response [200]>
# Pulling data for ust-maya. Response: <Response [200]>
# Pulling data for richards bay. Response: <Response [200]>
# Pulling data for longyearbyen. Response: <Response [200]>
# Pulling data for ginda. Response: <Response [200]>
# Pulling data for east london. Response: <Response [200]>
# Cannot find city vaitupu.
# Pulling data for pemba. Response: <Response [200]>
# Pulling data for nuuk. Response: <Response [200]>
# Pulling data for saint-philippe. Response: <Response [200]>
# Cannot find city meyungs.
# Pulling data for acapulco. Response: <Response [200]>
# Pulling data for butaritari. Response: <Response [200]>
# Cannot find city bengkulu.
# Pulling data for kolpny. Response: <Response [200]>
# Pulling data for kodiak. Response: <Response [200]>
# Pulling data for forbes. Response: <Response [200]>
# Pulling data for novokruchininskiy. Response: <Response [200]>
# Pulling data for shiggaon. Response: <Response [200]>
# Pulling data for diamantino. Response: <Response [200]>
# Pulling data for port elizabeth. Response: <Response [200]>
# Pulling data for kondinskoye. Response: <Response [200]>
# Pulling data for ati. Response: <Response [200]>
# Pulling data for jinxiang. Response: <Response [200]>
# Pulling data for novyy urgal. Response: <Response [200]>
# Pulling data for oriximina. Response: <Response [200]>
# Pulling data for fortuna foothills. Response: <Response [200]>
# Pulling data for harsin. Response: <Response [200]>
# Cannot find city korla.
# Cannot find city ciras.
# Pulling data for saskylakh. Response: <Response [200]>
# Pulling data for wilmington. Response: <Response [200]>
# Pulling data for fortuna. Response: <Response [200]>
# Pulling data for jamestown. Response: <Response [200]>
# Pulling data for vao. Response: <Response [200]>
# Pulling data for butembo. Response: <Response [200]>
# Pulling data for muros. Response: <Response [200]>
# Pulling data for coihaique. Response: <Response [200]>
# Pulling data for mayya. Response: <Response [200]>
# Pulling data for salalah. Response: <Response [200]>
# Pulling data for nome. Response: <Response [200]>
# Pulling data for hof. Response: <Response [200]>
# Cannot find city dubenskiy.
# Pulling data for copiapo. Response: <Response [200]>
# Pulling data for geraldton. Response: <Response [200]>
# Pulling data for ostuni. Response: <Response [200]>
# Pulling data for katsuura. Response: <Response [200]>
# Cannot find city kadykchan.
# Pulling data for lagos. Response: <Response [200]>
# Pulling data for ashland. Response: <Response [200]>
# Pulling data for mosquera. Response: <Response [200]>
# Pulling data for egvekinot. Response: <Response [200]>
# Pulling data for humberto de campos. Response: <Response [200]>
# Pulling data for airai. Response: <Response [200]>
# Pulling data for nyurba. Response: <Response [200]>
# Pulling data for kaitangata. Response: <Response [200]>
# Pulling data for santa maria del oro. Response: <Response [200]>
# Pulling data for chenghai. Response: <Response [200]>
# Pulling data for hithadhoo. Response: <Response [200]>
# Pulling data for katherine. Response: <Response [200]>
# Pulling data for tiarei. Response: <Response [200]>
# Pulling data for kentau. Response: <Response [200]>
# Cannot find city lemesos.
# Pulling data for saint albans. Response: <Response [200]>
# Pulling data for saldanha. Response: <Response [200]>
# Pulling data for sao felix do xingu. Response: <Response [200]>
# Cannot find city marcona.
# Pulling data for atuona. Response: <Response [200]>
# Pulling data for hami. Response: <Response [200]>
# Cannot find city illoqqortoormiut.
# Pulling data for guerrero negro. Response: <Response [200]>
# Pulling data for wanning. Response: <Response [200]>
# Pulling data for kaeo. Response: <Response [200]>
# Pulling data for padang. Response: <Response [200]>
# Pulling data for gat. Response: <Response [200]>
# Pulling data for narsaq. Response: <Response [200]>
# Pulling data for mahebourg. Response: <Response [200]>
# Cannot find city tabiauea.
# Cannot find city belushya guba.
# Pulling data for sorong. Response: <Response [200]>
# Pulling data for sarkhej. Response: <Response [200]>
# Pulling data for sioux lookout. Response: <Response [200]>
# Pulling data for rantepao. Response: <Response [200]>
# Pulling data for tigil. Response: <Response [200]>
# Pulling data for bad langensalza. Response: <Response [200]>
# Pulling data for kapaa. Response: <Response [200]>
# Pulling data for fereydunshahr. Response: <Response [200]>
# Pulling data for north bend. Response: <Response [200]>
# Pulling data for marawi. Response: <Response [200]>
# Pulling data for kearney. Response: <Response [200]>
# Pulling data for rodrigues alves. Response: <Response [200]>
# Pulling data for comodoro rivadavia. Response: <Response [200]>
# Pulling data for touros. Response: <Response [200]>
# Pulling data for lompoc. Response: <Response [200]>
# Pulling data for vila franca do campo. Response: <Response [200]>
# Pulling data for coquimbo. Response: <Response [200]>
# Pulling data for castro. Response: <Response [200]>
# Pulling data for state college. Response: <Response [200]>
# Pulling data for esperance. Response: <Response [200]>
# Pulling data for raudeberg. Response: <Response [200]>
# Pulling data for tuatapere. Response: <Response [200]>
# Pulling data for idritsa. Response: <Response [200]>
# Pulling data for salmas. Response: <Response [200]>
# Pulling data for tiksi. Response: <Response [200]>
# Cannot find city nizhneyansk.
# Pulling data for chokurdakh. Response: <Response [200]>
# Pulling data for bambous virieux. Response: <Response [200]>
# Pulling data for camalu. Response: <Response [200]>
# Pulling data for sambava. Response: <Response [200]>
# Pulling data for suozhen. Response: <Response [200]>
# Pulling data for vostok. Response: <Response [200]>
# Cannot find city andevoranto.
# Cannot find city phan rang.
# Cannot find city palabuhanratu.
# Pulling data for hwange. Response: <Response [200]>
# Cannot find city attawapiskat.
# Pulling data for hermanus. Response: <Response [200]>
# Pulling data for korem. Response: <Response [200]>
# Cannot find city puerto gaitan.
# Pulling data for sume. Response: <Response [200]>
# Pulling data for terre-de-bas. Response: <Response [200]>
# Pulling data for riyadh. Response: <Response [200]>
# Pulling data for luyang. Response: <Response [200]>
# Pulling data for makakilo city. Response: <Response [200]>
# Pulling data for shubarshi. Response: <Response [200]>
# Pulling data for atar. Response: <Response [200]>
# Cannot find city malwan.
# Pulling data for norman wells. Response: <Response [200]>
# Pulling data for daru. Response: <Response [200]>
# Pulling data for aliwal north. Response: <Response [200]>
# Pulling data for bacungan. Response: <Response [200]>
# Pulling data for kem. Response: <Response [200]>
# Pulling data for sabang. Response: <Response [200]>
# Pulling data for pierre. Response: <Response [200]>
# Pulling data for aksu. Response: <Response [200]>
# Pulling data for appleton. Response: <Response [200]>
# Pulling data for springdale. Response: <Response [200]>
# Pulling data for saint george. Response: <Response [200]>
# Pulling data for hasaki. Response: <Response [200]>
# Pulling data for beisfjord. Response: <Response [200]>
# Pulling data for victoria. Response: <Response [200]>
# Pulling data for port hardy. Response: <Response [200]>
# Pulling data for ust-kut. Response: <Response [200]>
# Cannot find city kamenskoye.
# Pulling data for faanui. Response: <Response [200]>
# Pulling data for grindavik. Response: <Response [200]>
# Pulling data for atraulia. Response: <Response [200]>
# Pulling data for mecca. Response: <Response [200]>
# Pulling data for barrow. Response: <Response [200]>
# Pulling data for jeremie. Response: <Response [200]>
# Pulling data for faya. Response: <Response [200]>
# Pulling data for dunedin. Response: <Response [200]>
# Pulling data for jiutai. Response: <Response [200]>
# Pulling data for hambantota. Response: <Response [200]>
# Pulling data for uvira. Response: <Response [200]>
# Pulling data for fairview. Response: <Response [200]>
# Pulling data for balkhash. Response: <Response [200]>
# Pulling data for carutapera. Response: <Response [200]>
# Pulling data for kangaatsiaq. Response: <Response [200]>
# Pulling data for whitehorse. Response: <Response [200]>
# Pulling data for pevek. Response: <Response [200]>
# Pulling data for ayame. Response: <Response [200]>
# Pulling data for pakhtakoron. Response: <Response [200]>
# Pulling data for lagoa. Response: <Response [200]>
# Pulling data for sao filipe. Response: <Response [200]>
# Cannot find city rungata.
# Pulling data for bud. Response: <Response [200]>
# Pulling data for tazovskiy. Response: <Response [200]>
# Pulling data for talnakh. Response: <Response [200]>
# Pulling data for biloela. Response: <Response [200]>
# Pulling data for lazaro cardenas. Response: <Response [200]>
# Pulling data for beringovskiy. Response: <Response [200]>
# Pulling data for sorland. Response: <Response [200]>
# Pulling data for kenai. Response: <Response [200]>
# Cannot find city chagda.
# Pulling data for merida. Response: <Response [200]>
# Pulling data for mar del plata. Response: <Response [200]>
# Pulling data for te anau. Response: <Response [200]>
# Pulling data for nyamuswa. Response: <Response [200]>
# Pulling data for gijon. Response: <Response [200]>
# Pulling data for mayumba. Response: <Response [200]>
# Pulling data for kawalu. Response: <Response [200]>
# Pulling data for camopi. Response: <Response [200]>
# Pulling data for sobolevo. Response: <Response [200]>
# Pulling data for colombia. Response: <Response [200]>
# Pulling data for margate. Response: <Response [200]>
# Pulling data for estelle. Response: <Response [200]>
# Pulling data for edea. Response: <Response [200]>
# Cannot find city tukrah.
# Pulling data for ust-omchug. Response: <Response [200]>
# Pulling data for sault sainte marie. Response: <Response [200]>
# Pulling data for upata. Response: <Response [200]>
# Pulling data for mezen. Response: <Response [200]>
# Pulling data for balabac. Response: <Response [200]>
# Pulling data for flin flon. Response: <Response [200]>
# Pulling data for carnarvon. Response: <Response [200]>
# Pulling data for berlevag. Response: <Response [200]>
# Pulling data for ebolowa. Response: <Response [200]>
# Pulling data for mayo. Response: <Response [200]>
# Pulling data for santiago. Response: <Response [200]>
# Pulling data for abu dhabi. Response: <Response [200]>
# Pulling data for bandarbeyla. Response: <Response [200]>
# Pulling data for kalispell. Response: <Response [200]>
# Pulling data for kahului. Response: <Response [200]>
# Pulling data for pisco. Response: <Response [200]>
# Cannot find city tanjong karang.
# Pulling data for brekstad. Response: <Response [200]>
# Cannot find city karamay.
# Pulling data for anadyr. Response: <Response [200]>
# Pulling data for brainerd. Response: <Response [200]>
# Pulling data for la orilla. Response: <Response [200]>
# Pulling data for kristiansund. Response: <Response [200]>
# Pulling data for tutoia. Response: <Response [200]>
# Pulling data for kampot. Response: <Response [200]>
# Pulling data for voyvozh. Response: <Response [200]>
# Pulling data for soyo. Response: <Response [200]>
# Pulling data for karakol. Response: <Response [200]>
# Pulling data for isola della scala. Response: <Response [200]>
# Pulling data for dzerzhinsk. Response: <Response [200]>
# Pulling data for gelemso. Response: <Response [200]>
# Pulling data for ambilobe. Response: <Response [200]>
# Pulling data for dergachi. Response: <Response [200]>
# Pulling data for wanxian. Response: <Response [200]>
# Pulling data for xichang. Response: <Response [200]>
# Pulling data for cherskiy. Response: <Response [200]>
# Pulling data for lavrentiya. Response: <Response [200]>
# Pulling data for guntakal. Response: <Response [200]>
# Pulling data for taiyuan. Response: <Response [200]>
# Pulling data for porto belo. Response: <Response [200]>
# Pulling data for masuda. Response: <Response [200]>
# Cannot find city miranorte.
# Pulling data for miri. Response: <Response [200]>
# Pulling data for iqaluit. Response: <Response [200]>
# Pulling data for maceio. Response: <Response [200]>
# Cannot find city karkaralinsk.
# Cannot find city tungkang.
# Pulling data for shar. Response: <Response [200]>
# Cannot find city tsihombe.
# Pulling data for tura. Response: <Response [200]>
# Pulling data for kokkola. Response: <Response [200]>
# Pulling data for iskateley. Response: <Response [200]>
# Pulling data for hereford. Response: <Response [200]>
# Pulling data for hirara. Response: <Response [200]>
# Pulling data for lathrop. Response: <Response [200]>
# Pulling data for puerto leguizamo. Response: <Response [200]>
# Pulling data for jalu. Response: <Response [200]>
# Pulling data for dauphin. Response: <Response [200]>
# Pulling data for clyde river. Response: <Response [200]>
# Pulling data for cidreira. Response: <Response [200]>
# Pulling data for saint-pierre. Response: <Response [200]>
# Pulling data for adrar. Response: <Response [200]>
# Pulling data for benjamin constant. Response: <Response [200]>
# Pulling data for weymouth. Response: <Response [200]>
# Pulling data for umm kaddadah. Response: <Response [200]>
# Pulling data for arlit. Response: <Response [200]>
# Pulling data for castilla. Response: <Response [200]>
# Pulling data for walvis bay. Response: <Response [200]>
# Pulling data for rio grande. Response: <Response [200]>
# Cannot find city tumannyy.
# Pulling data for pilar. Response: <Response [200]>
# Pulling data for kalmunai. Response: <Response [200]>
# Pulling data for soe. Response: <Response [200]>
# Pulling data for villanueva de la serena. Response: <Response [200]>
# Pulling data for williams lake. Response: <Response [200]>
# Pulling data for komsomolskiy. Response: <Response [200]>
# Pulling data for hofn. Response: <Response [200]>
# Pulling data for half moon bay. Response: <Response [200]>
# Cannot find city rawah.
# Pulling data for karratha. Response: <Response [200]>
# Pulling data for saint-joseph. Response: <Response [200]>
# Cannot find city gurskoye.
# Pulling data for bastia. Response: <Response [200]>
# Pulling data for ahuimanu. Response: <Response [200]>
# Pulling data for manta. Response: <Response [200]>
# Pulling data for briancon. Response: <Response [200]>
# Pulling data for upernavik. Response: <Response [200]>
# Pulling data for yongan. Response: <Response [200]>
# Pulling data for boende. Response: <Response [200]>
# Pulling data for leningradskiy. Response: <Response [200]>
# Pulling data for sistranda. Response: <Response [200]>
# Pulling data for baturaja. Response: <Response [200]>
# Pulling data for lieksa. Response: <Response [200]>
# Pulling data for georgetown. Response: <Response [200]>
# Pulling data for fort nelson. Response: <Response [200]>
# Pulling data for camocim. Response: <Response [200]>
# Pulling data for qasigiannguit. Response: <Response [200]>
# Pulling data for hay river. Response: <Response [200]>
# Pulling data for vila do maio. Response: <Response [200]>
# Pulling data for cabedelo. Response: <Response [200]>
# Pulling data for aswan. Response: <Response [200]>
# Pulling data for coruripe. Response: <Response [200]>
# Pulling data for port macquarie. Response: <Response [200]>
# Pulling data for rongcheng. Response: <Response [200]>
# Pulling data for gizo. Response: <Response [200]>
# Pulling data for bhum. Response: <Response [200]>
# Pulling data for vestmannaeyjar. Response: <Response [200]>
# Pulling data for souillac. Response: <Response [200]>
# Pulling data for luganville. Response: <Response [200]>
# Pulling data for zhangjiakou. Response: <Response [200]>
# Pulling data for sanchursk. Response: <Response [200]>
# Pulling data for yakeshi. Response: <Response [200]>
# Pulling data for kachug. Response: <Response [200]>
# Pulling data for sam roi yot. Response: <Response [200]>
# Pulling data for madingou. Response: <Response [200]>
# Pulling data for karla. Response: <Response [200]>
# Pulling data for batagay-alyta. Response: <Response [200]>
# Cannot find city tarland.
# Pulling data for fairbanks. Response: <Response [200]>
# Pulling data for luderitz. Response: <Response [200]>
# Pulling data for naze. Response: <Response [200]>
# Pulling data for evensk. Response: <Response [200]>
# Pulling data for vavuniya. Response: <Response [200]>
# Pulling data for kutum. Response: <Response [200]>
# Pulling data for linkou. Response: <Response [200]>
# Pulling data for jumla. Response: <Response [200]>
# Pulling data for shakawe. Response: <Response [200]>
# Pulling data for sulangan. Response: <Response [200]>
# Pulling data for belyy yar. Response: <Response [200]>
# Pulling data for akdepe. Response: <Response [200]>
# Pulling data for codrington. Response: <Response [200]>
# Pulling data for sombrio. Response: <Response [200]>
# Pulling data for ilhabela. Response: <Response [200]>
# Cannot find city umzimvubu.
# Pulling data for parit buntar. Response: <Response [200]>
# Pulling data for paamiut. Response: <Response [200]>
# Pulling data for quang ngai. Response: <Response [200]>
# Pulling data for san cristobal. Response: <Response [200]>
# Pulling data for broken hill. Response: <Response [200]>
# Pulling data for sur. Response: <Response [200]>
# Pulling data for svay rieng. Response: <Response [200]>
# Pulling data for parana. Response: <Response [200]>
# Pulling data for amapa. Response: <Response [200]>
# Pulling data for san luis. Response: <Response [200]>
# Pulling data for bethel. Response: <Response [200]>
# Pulling data for vardo. Response: <Response [200]>
# Pulling data for hamilton. Response: <Response [200]>
# Pulling data for marzuq. Response: <Response [200]>
# Pulling data for ormara. Response: <Response [200]>
# Pulling data for namatanai. Response: <Response [200]>
# Cannot find city ndele.
# Pulling data for alice springs. Response: <Response [200]>
# Pulling data for havoysund. Response: <Response [200]>
# Pulling data for high level. Response: <Response [200]>
# Pulling data for plettenberg bay. Response: <Response [200]>
# Pulling data for nova olinda do norte. Response: <Response [200]>
# Pulling data for danielskuil. Response: <Response [200]>
# Pulling data for westport. Response: <Response [200]>
# Pulling data for oistins. Response: <Response [200]>
# Pulling data for hakui. Response: <Response [200]>
# Pulling data for araouane. Response: <Response [200]>
# Cannot find city samusu.
# Pulling data for podares. Response: <Response [200]>
# Pulling data for kavaratti. Response: <Response [200]>
# Pulling data for najran. Response: <Response [200]>
# Pulling data for cayenne. Response: <Response [200]>
# Pulling data for tupik. Response: <Response [200]>
# Pulling data for vanavara. Response: <Response [200]>
# Cannot find city louisbourg.
# Pulling data for jaciara. Response: <Response [200]>
# Pulling data for victor harbor. Response: <Response [200]>
# Pulling data for waddan. Response: <Response [200]>
# Pulling data for jinan. Response: <Response [200]>
# Pulling data for klyuchevskiy. Response: <Response [200]>
# Pulling data for mana. Response: <Response [200]>
# Pulling data for gejiu. Response: <Response [200]>
# Pulling data for palmer. Response: <Response [200]>
# Pulling data for manokwari. Response: <Response [200]>
# Pulling data for koumac. Response: <Response [200]>
# Pulling data for port-gentil. Response: <Response [200]>
# Pulling data for somerset east. Response: <Response [200]>
# Pulling data for kokopo. Response: <Response [200]>
# Pulling data for rioja. Response: <Response [200]>
# Pulling data for pandamatenga. Response: <Response [200]>
# Cannot find city alappuzha.
# Pulling data for fare. Response: <Response [200]>
# Pulling data for beloha. Response: <Response [200]>
# Pulling data for beian. Response: <Response [200]>
# Pulling data for puerto colombia. Response: <Response [200]>
# Pulling data for werda. Response: <Response [200]>
# Pulling data for saint-augustin. Response: <Response [200]>
# Cannot find city arrecife.
# Cannot find city sentyabrskiy.
# Pulling data for cockburn town. Response: <Response [200]>
# Pulling data for charyshskoye. Response: <Response [200]>
# Pulling data for lebu. Response: <Response [200]>
# Pulling data for anchorage. Response: <Response [200]>
# Pulling data for nizhniy tsasuchey. Response: <Response [200]>
# Pulling data for san patricio. Response: <Response [200]>
# Pulling data for petropavlovsk-kamchatskiy. Response: <Response [200]>
# Pulling data for viiratsi. Response: <Response [200]>
# Pulling data for chimbote. Response: <Response [200]>
# Pulling data for warrnambool. Response: <Response [200]>
# Pulling data for nishihara. Response: <Response [200]>
# Pulling data for nokaneng. Response: <Response [200]>
# Pulling data for sabinas hidalgo. Response: <Response [200]>
# Pulling data for dzaoudzi. Response: <Response [200]>
# Pulling data for malanje. Response: <Response [200]>
# Pulling data for okhotsk. Response: <Response [200]>
# Pulling data for eisiskes. Response: <Response [200]>
# Pulling data for kontagora. Response: <Response [200]>
# Pulling data for chifeng. Response: <Response [200]>
# Cannot find city lolua.
# Pulling data for peniche. Response: <Response [200]>
# Cannot find city kawana waters.
# Pulling data for vera cruz. Response: <Response [200]>
# Pulling data for wanaka. Response: <Response [200]>
# Pulling data for gemena. Response: <Response [200]>
# Pulling data for murashi. Response: <Response [200]>
# Pulling data for samarai. Response: <Response [200]>
# Cannot find city kuche.
# Pulling data for kruisfontein. Response: <Response [200]>
# Pulling data for qaqortoq. Response: <Response [200]>
# Pulling data for jilib. Response: <Response [200]>
# Pulling data for ocos. Response: <Response [200]>
# Pulling data for mount gambier. Response: <Response [200]>
# Pulling data for saint anthony. Response: <Response [200]>
# Pulling data for catalina foothills. Response: <Response [200]>
# Cannot find city yomitan.
# Cannot find city gogrial.
# Pulling data for la ronge. Response: <Response [200]>
# Pulling data for sheksna. Response: <Response [200]>
# Pulling data for khandyga. Response: <Response [200]>
# Cannot find city varadero.
# Cannot find city barbar.
# Pulling data for nouakchott. Response: <Response [200]>
# Pulling data for balkanabat. Response: <Response [200]>
# Pulling data for hoa binh. Response: <Response [200]>
# Pulling data for simplicio mendes. Response: <Response [200]>
# Pulling data for kavieng. Response: <Response [200]>
# Pulling data for severo-kurilsk. Response: <Response [200]>
# Pulling data for canmore. Response: <Response [200]>
# Pulling data for paciran. Response: <Response [200]>
# Cannot find city warqla.
# Pulling data for oroquieta. Response: <Response [200]>
# Cannot find city samalaeulu.
# Pulling data for puksoozero. Response: <Response [200]>
# Pulling data for olinda. Response: <Response [200]>
# Pulling data for abrau-dyurso. Response: <Response [200]>
# Pulling data for cavalcante. Response: <Response [200]>
# Pulling data for tanout. Response: <Response [200]>
# Pulling data for bobcaygeon. Response: <Response [200]>
# Pulling data for kirakira. Response: <Response [200]>
# Pulling data for tacuarembo. Response: <Response [200]>
# Pulling data for kosonsoy. Response: <Response [200]>
# Pulling data for kidal. Response: <Response [200]>
# Pulling data for buta. Response: <Response [200]>
# Pulling data for namibe. Response: <Response [200]>
# Pulling data for san vicente. Response: <Response [200]>
# Pulling data for dicabisagan. Response: <Response [200]>
# Pulling data for ca mau. Response: <Response [200]>
# Pulling data for chinhoyi. Response: <Response [200]>
# Pulling data for ingham. Response: <Response [200]>
# Cannot find city marv dasht.
# Pulling data for znamenskoye. Response: <Response [200]>
# Pulling data for kerrville. Response: <Response [200]>
# Pulling data for kudahuvadhoo. Response: <Response [200]>
# Pulling data for skibbereen. Response: <Response [200]>
# Pulling data for ternate. Response: <Response [200]>
# Pulling data for wajid. Response: <Response [200]>
# Pulling data for nizhnyaya salda. Response: <Response [200]>
# Pulling data for pondicherry. Response: <Response [200]>
# Pulling data for brighton. Response: <Response [200]>
# Pulling data for keshod. Response: <Response [200]>
# Pulling data for reconquista. Response: <Response [200]>
# Pulling data for cambrils. Response: <Response [200]>
# Pulling data for kurilsk. Response: <Response [200]>
# Pulling data for kefamenanu. Response: <Response [200]>
# Pulling data for galesong. Response: <Response [200]>
# Pulling data for mwinilunga. Response: <Response [200]>
# Pulling data for oranjemund. Response: <Response [200]>
# Pulling data for baykit. Response: <Response [200]>
# Pulling data for dosso. Response: <Response [200]>
# Cannot find city bolungarvik.
# Cannot find city olafsvik.
# Pulling data for kashan. Response: <Response [200]>
# Pulling data for rabo de peixe. Response: <Response [200]>
# Pulling data for khotynets. Response: <Response [200]>
# Pulling data for dudinka. Response: <Response [200]>
# Pulling data for coria. Response: <Response [200]>
# Cannot find city tarudant.
# Pulling data for bull savanna. Response: <Response [200]>
# Pulling data for kotel. Response: <Response [200]>
# Pulling data for kiunga. Response: <Response [200]>
# Pulling data for lakes entrance. Response: <Response [200]>
# Pulling data for barra do garcas. Response: <Response [200]>
# Pulling data for akrata. Response: <Response [200]>
# Pulling data for road town. Response: <Response [200]>
# Pulling data for knyaze-volkonskoye. Response: <Response [200]>
# Pulling data for ahipara. Response: <Response [200]>
# Pulling data for youghal. Response: <Response [200]>
# Pulling data for jacqueville. Response: <Response [200]>
# Pulling data for pamanukan. Response: <Response [200]>
# Pulling data for cortez. Response: <Response [200]>
# Pulling data for arrifes. Response: <Response [200]>
# Pulling data for port augusta. Response: <Response [200]>
# Pulling data for maraba. Response: <Response [200]>
# Pulling data for beinamar. Response: <Response [200]>
# Cannot find city mrirt.
# Pulling data for lhokseumawe. Response: <Response [200]>
# Pulling data for moa. Response: <Response [200]>
# Pulling data for nata. Response: <Response [200]>
# Pulling data for nhulunbuy. Response: <Response [200]>
# Pulling data for micheweni. Response: <Response [200]>
# Cannot find city tongsa.
# Pulling data for voh. Response: <Response [200]>
# Pulling data for inuvik. Response: <Response [200]>
# Pulling data for coos bay. Response: <Response [200]>
# Cannot find city kerteh.
# Pulling data for natal. Response: <Response [200]>
# Pulling data for avera. Response: <Response [200]>
# Pulling data for caiaponia. Response: <Response [200]>
# Pulling data for pacific grove. Response: <Response [200]>
# Pulling data for san policarpo. Response: <Response [200]>
# Pulling data for buin. Response: <Response [200]>
# Pulling data for turukhansk. Response: <Response [200]>
# Pulling data for marsabit. Response: <Response [200]>
# Pulling data for mizan teferi. Response: <Response [200]>
# Cannot find city sedelnikovo.
# Cannot find city pagman.
# Pulling data for honningsvag. Response: <Response [200]>
# Pulling data for luangwa. Response: <Response [200]>
# Pulling data for kungurtug. Response: <Response [200]>
# Pulling data for yining. Response: <Response [200]>
# Pulling data for maha sarakham. Response: <Response [200]>
# Pulling data for bubaque. Response: <Response [200]>
# Cannot find city rostaq.
# Pulling data for shimoda. Response: <Response [200]>
# Pulling data for sovetskaya gavan. Response: <Response [200]>
# Cannot find city ruian.
# Pulling data for zhigalovo. Response: <Response [200]>
# Pulling data for bisira. Response: <Response [200]>
# Pulling data for taltal. Response: <Response [200]>
# Pulling data for nkhata bay. Response: <Response [200]>
# Pulling data for la libertad. Response: <Response [200]>
# Pulling data for arman. Response: <Response [200]>
# 548

# %%
# Data Storage
names =[]
clouds =[]
lats = []
lons = []
countries = []
dates = []
maxtemps = []
windspds = []
humids = []

# Building Dataframe
for cities in city_data:
    names.append(cities['name'])
    clouds.append(cities['clouds']['all'])
    lats.append(cities['coord']['lat'])
    lons.append(cities['coord']['lon'])
    countries.append(cities['sys']['country'])
    dates.append(cities['dt'])
    maxtemps.append(cities['main']['temp_max'])
    windspds.append(cities['wind']['speed'])
    humids.append(cities['main']['humidity'])

cities_df = pd.DataFrame({"City":names,"Cloudiness":clouds,"Country":countries,"Date":dates,"Humidity":humids,
                          "Latitude":lats,"Longitude":lons,"Max Temp (F)":maxtemps,"Wind Speed":windspds})
cities_df.head()
cities_df.to_csv("DataFigs/city_data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
cities_df.plot(kind="scatter",x="Latitude",y="Max Temp (F)")
plt.grid()
plt.title("Maximum Temperatures based on Latitude")
plt.show()
plt.savefig("DataFigs/temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
cities_df.plot(kind="scatter",x="Latitude",y="Humidity")
plt.grid()
plt.title("Humidity based on Latitude")
plt.show()
plt.savefig("DataFigs/humid.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cities_df.plot(kind="scatter",x="Latitude",y="Cloudiness")
plt.grid()
plt.title("Cloudiness based on Latitude")
plt.show()
plt.savefig("DataFigs/clouds.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
cities_df.plot(kind="scatter",x="Latitude",y="Wind Speed")
plt.grid()
plt.title("Wind Speeds based on Latitude")
plt.show()
plt.savefig("DataFigs/wind_spd.png")
